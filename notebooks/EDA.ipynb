# %%
import pandas as pd

df = pd.read_csv("../data/data.csv")
df.head()
# Out:
#    price  competitor_price  discount  rating  stock  views  price_diff  demand
# 0     61                47        16     2.0    322    100         -14       0
# 1     24                93        17     3.0    180    836          69       1
# 2     81                32        44     3.7    422    198         -49       0
# 3     70                54        28     2.4     77    780         -16       0
# 4     30                61        19     2.3    439    171          31       0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             2000 non-null   int64
#  1   competitor_price  2000 non-null   int64
#  2   discount          2000 non-null   int64
#  3   rating            2000 non-null   float64
#  4   stock             2000 non-null   int64
#  5   views             2000 non-null   int64
#  6   price_diff        2000 non-null   int64
#  7   demand            2000 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 125.1 KB
#             price  competitor_price     discount       rating        stock  \
# count  2000.00000       2000.000000  2000.000000  2000.000000  2000.000000
# mean     53.43900         53.768500    24.579500     3.468300   247.775500
# std      26.05294         25.964437    14.456665     0.872047   139.913377
# min      10.00000         10.000000     0.000000     2.000000     0.000000
# 25%      31.00000         31.000000    12.000000     2.700000   127.750000
# 50%      53.00000         53.000000    24.000000     3.500000   245.500000
# 75%      75.00000         76.000000    37.000000     4.200000   364.000000
# max      99.00000         99.000000    49.000000     5.000000   499.000000
#
#              views  price_diff       demand
# count  2000.000000  2000.00000  2000.000000
# mean    533.661500     0.32950     0.500000
# std     274.621549    36.68674     0.500125
# min      50.000000   -89.00000     0.000000
# 25%     293.000000   -26.00000     0.000000
# 50%     539.500000     1.00000     0.500000
# 75%     776.250000    28.00000     1.000000
# max     999.000000    88.00000     1.000000

# %%
df.isnull().sum()
# Out:
# price               0
# competitor_price    0
# discount            0
# rating              0
# stock               0
# views               0
# price_diff          0
# demand              0
# dtype: int64

# %%
df["demand"].value_counts()
# Out:
# demand
# 0    1000
# 1    1000
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
df.hist(figsize=(10,8))
plt.show()
